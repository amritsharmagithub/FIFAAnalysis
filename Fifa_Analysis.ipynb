# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #import all the libraries

# %%
fifa = pd.read_csv('fifa_data.csv') #reading CSV in Jupyter notebook

# %% [markdown]
# ## Different FIFA players

# %%
fifa
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %% [markdown]
# ## Distribution of Player skills

# %%
interval = [40,50,60,70,80,90,100] #intervals to select the range

plt.hist(fifa.Overall, bins=interval, color = '#83f442')
plt.xticks(interval)
plt.ylabel ('Skill Level')
plt.xlabel ('Number of Players')
plt.title('Distribution of Player skills in FIFA')
plt.show()

# %% [markdown]
# ## Players with Left vs Right foot

# %%
import matplotlib.pyplot as plt

#total count of left and right foot preferences
left_count = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right_count = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

# Calculate the total count of players
total_players = left_count + right_count

# Calculate the percentage of left and right foot preferences
left_percentage = (left_count / total_players) * 100
right_percentage = (right_count / total_players) * 100

#labels in Pie Chart
labels = ['Left', 'Right']
colors = ['#abcdef', '#aabbcc']

# Plot the pie chart with percentages and labels inside
plt.pie([left_count, right_count], labels=labels, colors=colors, autopct='%1.1f%%', pctdistance=0.85)
plt.title('Foot Preference of FIFA players')
plt.show()

# %% [markdown]
# ## Players Age group

# %%
import matplotlib.pyplot as plt

#figure size
plt.figure(figsize=(6, 4))

# histogram of players
plt.hist(fifa['Age'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Player Ages')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Countries with highest number of Players

# %%
import matplotlib.pyplot as plt

# top 10 countries with the highest number of players
top_countries = fifa['Nationality'].value_counts().head(10)

# Plot the bar plot
plt.figure(figsize=(10, 6))
top_countries.plot(kind='bar', color='skyblue')
plt.xlabel('Country')
plt.ylabel('Number of Players')
plt.title('Top 10 Countries with Highest Number of Players')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## Comparing Messi and Ronaldo

# %%
new_df = fifa[fifa['Name'].str.contains('Cristiano Ronaldo|L. Messi', case=False)]

#filtering out Messi and Ronaldo

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# smaller figure size
fig, axes = plt.subplots(1, 3, figsize=(8, 5))

new_df = fifa[fifa['Name'].str.contains('Cristiano Ronaldo|L. Messi', case=False)]


# Overall Performance distribution
sns.histplot(data=new_df, x='Overall', bins=20, kde=True, color='orange', ax=axes[0])
axes[0].set_title('Overall Performance Distribution')
axes[0].set_xlabel('Overall Rating')
axes[0].set_ylabel('Frequency')

# Plot Potential distribution
sns.histplot(data=new_df, x='Potential', bins=20, kde=True, color='green', ax=axes[1])
axes[1].set_title('Potential Distribution')
axes[1].set_xlabel('Potential Rating')
axes[1].set_ylabel('Frequency')

# Plot Composure distribution
sns.histplot(data=new_df, x='Composure', bins=20, kde=True, color='red', ax=axes[2])
axes[2].set_title('Composure Distribution')
axes[2].set_xlabel('Composure')
axes[2].set_ylabel('Frequency')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
fifa.head(20)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
# 15          15  211110          P. Dybala   24
# 16          16  202126            H. Kane   24
# 17          17  194765       A. Griezmann   27
# 18          18  192448      M. ter Stegen   26
# ...

# %% [markdown]
# ## Comparison of player ratings in different clubs

# %%
import matplotlib.pyplot as plt
import numpy as np

clubs = ['Real Madrid', 'Manchester United', 'FC Barcelona', 'Juventus', 'Paris Saint-Germain', 'Napoli']
club_data = []

for club in clubs:
    club_data.append(fifa.loc[fifa.Club == club]['Overall'])

plt.figure(figsize=(7, 3))

# Calculate the mean overall rating for each club
mean_ratings = [np.mean(data) for data in club_data]

# Plotting the horizontal bar chart
bars = plt.barh(clubs, mean_ratings, color='skyblue')
plt.xlabel('Average Overall Rating')
plt.title('Average Overall Player Ratings Among Football Clubs')
plt.grid(axis='x')

# Annotating each bar with its value
for bar, rating in zip(bars, mean_ratings):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{rating:.2f}', va='center')

plt.show()

# %% [markdown]
# ## Comparison of different attributes of different players

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Drop the first column by column name
fifa = fifa.drop(columns=['Unnamed: 0'])

# Alternatively, you can drop the first column by index
# fifa = fifa.drop(columns=[fifa.columns[0]])

# Players to analyze
players_to_analyze = ['Cristiano Ronaldo', 'L. Messi', 'L. Suárez', 'Neymar Jr', 'E. Hazard']

# Filter the DataFrame for the specified players
players_data = fifa[fifa['Name'].isin(players_to_analyze)]

# Plotting all headers for each player
for player in players_to_analyze:
    player_data = players_data[players_data['Name'] == player]
    plt.figure(figsize=(10, 6))
    plt.title(f"{player}")
    sns.barplot(data=player_data.drop(columns=['ID', 'Name']), orient='h')
    plt.xlabel('Attribute Value')
    plt.ylabel('Attribute')
    plt.show()
